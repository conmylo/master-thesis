# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag
import nltk
import enchant

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Initialize spell checker
spell_checker = enchant.Dict("en_US")


def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())  # Convert text to lowercase for consistency

    # Perform part-of-speech tagging
    pos_tags = pos_tag(tokens)

    return tokens, pos_tags


def calculate_spelling_accuracy(tokens):
    # Calculate the spelling accuracy percentage
    total_words = len(tokens)
    correctly_spelled_words = sum(1 for word in tokens if spell_checker.check(word))
    spelling_accuracy = correctly_spelled_words / total_words if total_words > 0 else 0

    return spelling_accuracy


def calculate_prompt_length(tokens):
    # Calculate the prompt length
    return len(tokens)


def calculate_pos_percentage(pos_tags, target_pos):
    # Calculate the percentage of specific parts of speech (e.g., nouns, verbs, adjectives)
    total_words = len(pos_tags)
    target_words = sum(1 for _, pos in pos_tags if pos.startswith(target_pos))
    pos_percentage = target_words / total_words if total_words > 0 else 0

    return pos_percentage


# Example usage
text = "Please make the following text more formal."
tokens, pos_tags = preprocess_text(text)
spelling_accuracy = calculate_spelling_accuracy(tokens)
prompt_length = calculate_prompt_length(tokens)
noun_percentage = calculate_pos_percentage(pos_tags, 'NN')

print("Tokens:", tokens)
print("Spelling Accuracy:", spelling_accuracy)
print("Prompt Length:", prompt_length)
print("Noun Percentage:", noun_percentage)
# Out:
# Tokens: ['please', 'make', 'the', 'following', 'text', 'more', 'formal', '.']
# Spelling Accuracy: 1.0
# Prompt Length: 8
# Noun Percentage: 0.125
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\conmy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\conmy\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import rasa
#       3 # Load pre-trained Rasa model
#       4 interpreter = rasa.nlu.model.Interpreter.load("path/to/pretrained_model")
#
# ModuleNotFoundError: No module named 'rasa'

# %%
import string

def count_sentences_and_punctuation(prompt):
    # Get user input
    user_input = input(prompt)
    
    # Count sentences
    sentences = user_input.split('.')
    num_sentences = len(sentences) - 1  # Subtract 1 for the empty string after the last period
    
    # Count punctuation marks
    punctuation_count = sum(1 for char in user_input if char in string.punctuation)
    
    return num_sentences, punctuation_count

# Prompt the user for input
user_prompt = "Enter a prompt: "
sentences, punctuation = count_sentences_and_punctuation(user_prompt)

# Output the result
print("Number of sentences:", sentences)
print("Number of punctuation marks:", punctuation)
# Out:
# Number of sentences: 3
# Number of punctuation marks: 3

# %%
import string
import nltk
nltk.download('punkt')

def count_sentences_and_punctuation(prompt):
    # Get user input
    user_input = input(prompt)
    
    # Tokenize the input into sentences
    sentences = nltk.sent_tokenize(user_input)
    num_sentences = len(sentences)
    
    # Count punctuation marks
    punctuation_count = sum(1 for char in user_input if char in string.punctuation)
    
    return num_sentences, punctuation_count

def count_length(prompt):
    # Get user input
    user_input = input(prompt)
    
    # Calculate length of input
    length = len(user_input)
    
    return length

# Prompt the user for input
user_prompt = "Enter a prompt: "
result = count_length(user_prompt)
sentences, punctuation = count_sentences_and_punctuation(user_prompt)

# Output the result
print("Number of sentences:", sentences)
print("Number of punctuation marks:", punctuation)
print("Length of input:", result)

# %%
import string

def count_sentences_punctuation_and_length(prompt):
    # Get user input
    user_input = input(prompt)
    
    # Count sentences
    sentences = user_input.split('.')
    num_sentences = len(sentences) - 1  # Subtract 1 for the empty string after the last period
    
    # Count punctuation marks
    punctuation_count = sum(1 for char in user_input if char in string.punctuation)
    
    # Calculate length of input
    length = len(user_input)
    
    return num_sentences, punctuation_count, length

# Prompt the user for input
user_prompt = "Enter a prompt: "
sentences, punctuation, result = count_sentences_punctuation_and_length(user_prompt)

# Output the results
print("Number of sentences:", sentences)
print("Number of punctuation marks:", punctuation)
print("Length of input:", result)
# Out:
# Enter a prompt: Hey! my name is kostas. and you? this is my face, hi.
# Number of sentences: 2
# Number of punctuation marks: 5
# Length of input: 53

# %%
import string
import nltk
from collections import Counter

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def count_sentences_punctuation_length_and_pos(prompt):
    # Get user input
    user_input = input(prompt)
    
    # Count sentences
    sentences = user_input.split('.')
    num_sentences = len(sentences) - 1  # Subtract 1 for the empty string after the last period
    
    # Count punctuation marks
    punctuation_count = sum(1 for char in user_input if char in string.punctuation)
    
    # Calculate length of input
    length = len(user_input)
    
    # Tokenize input into words
    words = nltk.word_tokenize(user_input)
    
    # Perform part-of-speech tagging
    pos_tags = nltk.pos_tag(words)
    
    # Count the occurrences of each part of speech
    pos_counts = Counter(tag for word, tag in pos_tags)
    
    return num_sentences, punctuation_count, length, pos_counts

# Prompt the user for input
user_prompt = "Enter a prompt: "
sentences, punctuation, result, pos_counts = count_sentences_punctuation_length_and_pos(user_prompt)

# Output the results
print("Number of sentences:", sentences)
print("Number of punctuation marks:", punctuation)
print("Length of input:", result)
print("Parts of speech counts:")
for pos, count in pos_counts.items():
    print(f"{pos}: {count}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\conmy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\conmy\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Enter a prompt: Hello. My name is Konstantinos. What is your name? My age is 20.
# Number of sentences: 3
# Number of punctuation marks: 4
# Length of input: 64
# Parts of speech counts:
# NNP: 2
# .: 4
# PRP$: 3
# NN: 3
# VBZ: 3
# WP: 1
# CD: 1

# %%
import string
import nltk
from collections import Counter

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def count_sentences_punctuation_length_and_pos(prompt):
    # Get user input
    user_input = input(prompt)
    
    # Count sentences
    sentences = user_input.split('.')
    num_sentences = len(sentences) - 1  # Subtract 1 for the empty string after the last period
    
    # Count punctuation marks
    punctuation_count = sum(1 for char in user_input if char in string.punctuation)
    
    # Calculate length of input
    length = len(user_input)
    
    # Tokenize input into words
    words = nltk.word_tokenize(user_input)
    
    # Perform part-of-speech tagging
    pos_tags = nltk.pos_tag(words)
    
    # Count the occurrences of each part of speech
    pos_counts = Counter(tag for word, tag in pos_tags)
    
    # Calculate percentages
    total_words = len(words)
    pos_percentages = {pos: (count / total_words) * 100 for pos, count in pos_counts.items()}
    
    return num_sentences, punctuation_count, length, pos_counts, pos_percentages

# Prompt the user for input
user_prompt = "Enter a prompt: "
sentences, punctuation, result, pos_counts, pos_percentages = count_sentences_punctuation_length_and_pos(user_prompt)

# Output the results
print("Number of sentences:", sentences)
print("Number of punctuation marks:", punctuation)
print("Length of input:", result)
print("Parts of speech counts:")
for pos, count in pos_counts.items():
    print(f"{pos}: {count} ({pos_percentages[pos]:.2f}% of the whole prompt)")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\conmy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\conmy\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Enter a prompt: Hello! my name is Konstantinos. What is your name?
# Number of sentences: 1
# Number of punctuation marks: 3
# Length of input: 50
# Parts of speech counts:
# NN: 3 (25.00% of the whole prompt)
# .: 3 (25.00% of the whole prompt)
# PRP$: 2 (16.67% of the whole prompt)
# VBZ: 2 (16.67% of the whole prompt)
# NNP: 1 (8.33% of the whole prompt)
# WP: 1 (8.33% of the whole prompt)

# %%
# Spelling accuracy included

import string
import nltk
from collections import Counter
from spellchecker import SpellChecker

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def count_sentences_punctuation_length_and_pos(prompt):
    # Get user input
    user_input = input(prompt)
    
    # Count sentences
    sentences = user_input.split('.')
    num_sentences = len(sentences) - 1  # Subtract 1 for the empty string after the last period
    
    # Count punctuation marks
    punctuation_count = sum(1 for char in user_input if char in string.punctuation)
    
    # Calculate length of input
    length = len(user_input)
    
    # Tokenize input into words
    words = nltk.word_tokenize(user_input)
    
    # Perform part-of-speech tagging
    pos_tags = nltk.pos_tag(words)
    
    # Count the occurrences of each part of speech
    pos_counts = Counter(tag for word, tag in pos_tags)
    
    # Calculate spelling accuracy
    spell = SpellChecker()
    misspelled = spell.unknown(words)
    spelling_accuracy = 100 - (len(misspelled) / len(words)) * 100
    
    return num_sentences, punctuation_count, length, pos_counts, spelling_accuracy

# Prompt the user for input
user_prompt = "Enter a prompt: "
sentences, punctuation, result, pos_counts, spelling_accuracy = count_sentences_punctuation_length_and_pos(user_prompt)

# Output the results
print("Number of sentences:", sentences)
print("Number of punctuation marks:", punctuation)
print("Length of input:", result)
print("Parts of speech counts:")
for pos, count in pos_counts.items():
    print(f"{pos}: {count}")
print(f"Spelling accuracy: {spelling_accuracy:.2f}%")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\conmy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\conmy\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Enter a prompt: Hello! what is your name? My name is.
# Number of sentences: 1
# Number of punctuation marks: 3
# Length of input: 37
# Parts of speech counts:
# NN: 3
# .: 3
# WP: 1
# VBZ: 2
# PRP$: 2
# Spelling accuracy: 100.00%
