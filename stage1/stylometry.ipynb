# %% [markdown]
# Stylometry using RNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
texts = [
    "This is a sample text written by the authorized user. The authorized user has a specific style.",
    "The authorized user often writes in short, clear sentences. This is another example of their style.",
    "Here is a text by an unauthorized user. This user writes in a different style, with more complex sentences.",
    "An unauthorized user tends to have varied sentence lengths and different vocabulary usage.",
    "Another unauthorized user writes with a very different style, using more technical language and complex structures.",
    "Unauthorized users do not have the same writing norm as the authorized user."
]

labels = ["authorized", "authorized", "unauthorized", "unauthorized", "unauthorized", "unauthorized"]

# %%
# Tokenize the texts
tokenizer = Tokenizer(num_words=1000)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded_sequences = pad_sequences(sequences, maxlen=20)

# Encode the labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, encoded_labels, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Embedding(input_dim=1000, output_dim=64, input_length=20))
model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# c:\Users\conmy\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.5000 - loss: 0.6912 - val_accuracy: 0.0000e+00 - val_loss: 0.6978
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.6809 - val_accuracy: 0.0000e+00 - val_loss: 0.7058
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.6695 - val_accuracy: 0.0000e+00 - val_loss: 0.7141
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.6645 - val_accuracy: 0.0000e+00 - val_loss: 0.7231
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.6502 - val_accuracy: 0.0000e+00 - val_loss: 0.7334
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.6401 - val_accuracy: 0.0000e+00 - val_loss: 0.7452
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.6246 - val_accuracy: 0.0000e+00 - val_loss: 0.7593
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.5963 - val_accuracy: 0.0000e+00 - val_loss: 0.7762
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.5989 - val_accuracy: 0.0000e+00 - val_loss: 0.7967
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.5528 - val_accuracy: 0.0000e+00 - val_loss: 0.8224

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.0000e+00 - loss: 0.8224
# Test Accuracy: 0.00%

# %%
def grant_access(text):
    # Preprocess the input text
    sequence = tokenizer.texts_to_sequences([text])
    padded_sequence = pad_sequences(sequence, maxlen=20)

    # Predict using the trained model
    prediction = model.predict(padded_sequence)[0][0]

    # Grant or deny access
    if prediction > 0.5:
        print("Access Granted: The writing style matches the authorized user.")
    else:
        print("Access Denied: The writing style does not match the authorized user.")

# Example usage
# new_text = "This is a new text that should be similar to the authorized user."
# new_text = "This is a new text that is not similar to the authorized user, who should be the only one that is granted access, and also is not similar to the unauthorized user."
# grant_access(new_text)

new_text = """
The technical intricacies of the proposed mechanism, involving a plethora of sophisticated algorithms, are elucidated with meticulous attention to detail, ensuring that the multifaceted nature of the process is comprehensively understood. This approach, though ostensibly complex, provides a nuanced understanding that is essential for grasping the underlying principles.
"""
grant_access(new_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Access Granted: The writing style matches the authorized user.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Access Granted: The writing style matches the authorized user.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Sample Dataset
texts = [
    "This is a sample text written by the authorized user. The authorized user has a specific style.",
    "The authorized user often writes in short, clear sentences. This is another example of their style.",
    "Here is a text by an unauthorized user. This user writes in a different style, with more complex sentences.",
    "An unauthorized user tends to have varied sentence lengths and different vocabulary usage.",
    "Another unauthorized user writes with a very different style, using more technical language and complex structures.",
    "Unauthorized users do not have the same writing norm as the authorized user."
]

labels = ["authorized", "authorized", "unauthorized", "unauthorized", "unauthorized", "unauthorized"]

# Tokenize and Pad Sequences
tokenizer = Tokenizer(num_words=1000)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded_sequences = pad_sequences(sequences, maxlen=20)

# Encode Labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# Split the Data
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, encoded_labels, test_size=0.2, random_state=42)

# Build the RNN Model
model = Sequential()
model.add(Embedding(input_dim=1000, output_dim=128, input_length=20))
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the Model
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

# Evaluate the Model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Access Control Function
def grant_access(text, threshold=0.7):  # Stricter threshold
    sequence = tokenizer.texts_to_sequences([text])
    padded_sequence = pad_sequences(sequence, maxlen=20)
    prediction = model.predict(padded_sequence)[0][0]

    print(f"Model Prediction: {prediction:.4f}")  # Debugging line

    if prediction > threshold:
        print("Access Granted: The writing style matches the authorized user.")
    else:
        print("Access Denied: The writing style does not match the authorized user.")

# Example Text Likely to Be Denied
new_text = """
The technical intricacies of the proposed mechanism, involving a plethora of sophisticated algorithms, are elucidated with meticulous attention to detail, ensuring that the multifaceted nature of the process is comprehensively understood. This approach, though ostensibly complex, provides a nuanced understanding that is essential for grasping the underlying principles.
"""
grant_access(new_text)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7500 - loss: 0.6904 - val_accuracy: 0.0000e+00 - val_loss: 0.6973
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.6761 - val_accuracy: 0.0000e+00 - val_loss: 0.7064
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.6690 - val_accuracy: 0.0000e+00 - val_loss: 0.7165
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.6492 - val_accuracy: 0.0000e+00 - val_loss: 0.7300
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.6358 - val_accuracy: 0.0000e+00 - val_loss: 0.7478
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.6003 - val_accuracy: 0.0000e+00 - val_loss: 0.7730
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.5828 - val_accuracy: 0.0000e+00 - val_loss: 0.8090
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.5308 - val_accuracy: 0.0000e+00 - val_loss: 0.8642
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.4978 - val_accuracy: 0.0000e+00 - val_loss: 0.9555
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.3912 - val_accuracy: 0.0000e+00 - val_loss: 1.1189
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0000e+00 - loss: 1.1189
# Test Accuracy: 0.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Model Prediction: 0.6591
# Access Denied: The writing style does not match the authorized user.

# %%
new_text = """
This is a simple example.
"""
grant_access(new_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Model Prediction: 0.8070
# Access Granted: The writing style matches the authorized user.
