# %% [markdown]
# Keystroke Dynamics with a Neural Network

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_keystroke_model():
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu', input_shape=(2,)))  # Assuming 2 features: avg dwell time and avg flight time
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Example usage
keystroke_model = build_keystroke_model()
# Train the model with keystroke data
keystroke_model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras import layers, models
#       4 def build_keystroke_model():
#
# File c:\Users\conmy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from tensorflow._api.v2 import __internal__
#      46 from tensorflow._api.v2 import __operators__
#      47 from tensorflow._api.v2 import audio
#
# File c:\Users\conmy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
# ...

# %% [markdown]
# Stylometry with a Recurrent Neural Network (RNN)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_stylometry_model(vocab_size, embedding_dim=128, rnn_units=64):
    model = models.Sequential()
    model.add(layers.Embedding(vocab_size, embedding_dim))
    model.add(layers.LSTM(rnn_units))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Example usage
stylometry_model = build_stylometry_model(vocab_size=5000)  # Assuming a vocabulary size of 5000 words
# Train the model with text data
stylometry_model.fit(X_train_text, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      13 stylometry_model = build_stylometry_model(vocab_size=5000)  # Assuming a vocabulary size of 5000 words
#      14 # Train the model with text data
# ---> 15 stylometry_model.fit(X_train_text, y_train, epochs=10, batch_size=32, validation_split=0.2)
#
# NameError: name 'X_train_text' is not defined
