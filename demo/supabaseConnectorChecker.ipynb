# %% [markdown]
# Install Supabase and connect to MasterThesis base to fetch data

# %%
# ! pip install supabase

# %%
# Import necessary libraries
from supabase import create_client, Client
import os

# Your Supabase URL and API Key
supabase_url = 'https://zjpccllcziydaciknrgd.supabase.co'  # Replace with your actual Supabase URL
supabase_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InpqcGNjbGxjeml5ZGFjaWtucmdkIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTY3MjEwMjAsImV4cCI6MjAzMjI5NzAyMH0.7zRbRiZ5CKNRQsrFO2TdlCIL4etXsEmkMWwfGgQuBAI'  # Replace with your Supabase API key

# Initialize the connection to Supabase
def init_supabase():
    return create_client(supabase_url, supabase_key)

# Test the connection by fetching data from the 'data_v1' table
def fetch_data_from_supabase(supabase: Client):
    try:
        response = supabase.table('data_v1').select('*').limit(10).execute()  # Fetch first 10 rows as a test
        if response.data:
            print("Connection successful! Data fetched from 'data_v1':")
            for row in response.data:
                print(row)
        else:
            print("Connection successful but no data found in 'data_v1'.")
    except Exception as e:
        print("Error fetching data from Supabase:", e)

# Initialize and test the connection
supabase = init_supabase()
fetch_data_from_supabase(supabase)
# Out:
# Connection successful! Data fetched from 'data_v1':
# {'user_id': 'User_001', 'raw_text': 'What is the fastest way to sum elements in a large array?', 'prompt_length': 40, 'sentiment': 'negative', 'topic': 'data_science', 'timestamp': '2023-09-20T18:00:27.349684', 'location': 'Europe/Thessaloníki', 'time_of_day': 'morning', 'stylometry_features.pos_tag_distribution.NN': 23.3, 'stylometry_features.pos_tag_distribution.VB': 25, 'stylometry_features.pos_tag_distribution.JJ': 28.4, 'stylometry_features.pos_tag_distribution.RB': 10.8, 'stylometry_features.pos_tag_distribution.PRP': 20.1, 'stylometry_features.grammar_usage.correct_sentences': 2, 'stylometry_features.grammar_usage.complex_sentences': 0, 'stylometry_features.average_word_length': 4.5, 'stylometry_features.lexical_diversity': 0.51, 'stylometry_features.readability_score': 9.5, 'keystroke_dynamics.average_key_press_time': 104, 'keystroke_dynamics.average_time_between_keystrokes': 114, 'keystroke_dynamics.backspace_count': 0}
# ...
